# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from seaborn) (2.4.1)
# Requirement already satisfied: pandas>=1.2 in c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from seaborn) (3.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

dataset = sns.load_dataset('titanic')

dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.distplot(dataset['fare'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_31276\1694218074.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['fare'])
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.distplot(dataset['fare'], kde=False)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_31276\1623915515.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['fare'], kde=False)
# <Axes: xlabel='fare'>

# %%
sns.jointplot(x='age', y='fare', data=dataset)

# %%
sns.rugplot(dataset['fare'])
# Out:
# <Axes: xlabel='fare'>

# %%
sns.barplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.countplot(x='sex', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(x='sex', y='age', data=dataset, hue="survived")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.swarmplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x='sex', y='age', data=dataset)
sns.swarmplot(x='sex', y='age', data=dataset, color='black')
# Out:
# <Axes: xlabel='sex', ylabel='age'>
# c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
numeric_dataset = dataset.select_dtypes(include=[np.number])
corr = dataset.corr()
sns.heatmap(corr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 numeric_dataset = dataset.select_dtypes(include=[np.number])
# ----> 2 corr = dataset.corr()
#       3 sns.heatmap(corr)
#
# File c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13115 cols = data.columns
#   13116 idx = cols.copy()
# > 13117 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13119 if method == "pearson":
#   13120     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2079 if dtype is not None:
#    2080     dtype = np.dtype(dtype)
# -> 2081 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2082 if result.dtype is not dtype:
#    2083     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\managers.py:1847, in BlockManager.as_array(self, dtype, copy, na_value)
#    1845         arr.flags.writeable = False
#    1846 else:
# -> 1847     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1848     # The underlying data was copied within _interleave, so no need
#    1849     # to further copy if copy=True or setting na_value
#    1851 if na_value is lib.no_default:
#
# File c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\managers.py:1900, in BlockManager._interleave(self, dtype, na_value)
#    1894 rl = blk.mgr_locs
#    1895 if blk.is_extension:
#    1896     # Avoid implicit conversion of extension blocks to object
#    1897
#    1898     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1899     # attribute "to_numpy"
# -> 1900     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1901         dtype=dtype,
#    1902         na_value=na_value,
#    1903     )
#    1904 else:
#    1905     arr = blk.get_values(dtype)
#
# File c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\arrays\numpy_.py:589, in NumpyExtensionArray.to_numpy(self, dtype, copy, na_value)
#     586         result = result.view()
#     587         result.flags.writeable = False
# --> 589 result = np.asarray(result, dtype=dtype)
#     591 if copy and result is self._ndarray:
#     592     result = result.copy()
#
# ValueError: could not convert string to float: 'male'
